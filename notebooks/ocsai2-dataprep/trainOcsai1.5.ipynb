# %% [markdown]
# # Train Ocsai 1.5

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import numpy as np
from ocsai.prompter import Ocsai1p5_Prompter
from pathlib import Path
import json
from tqdm.auto import tqdm
import openai
from collections import defaultdict
import tiktoken
import time
client = openai.OpenAI()

# %%
prompter = Ocsai1p5_Prompter()

# %%
data = pd.read_csv('../../data/ocsai-all.csv')
data_dir = Path('../../data/training/gpt')
data_dir.mkdir(exist_ok=True, parents=True)
# Out:
# /var/folders/k2/vg86l2h54czgjfzlmd6fkz908bdx0t/T/ipykernel_29559/324456786.py:1: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('../../data/ocsai-all.csv')

# %%
data.groupby(['language', 'type']).size()
# Out:
# language  type
# ara       uses              923
# chi       uses            16589
# dut       uses             7139
# eng       completion       2797
#           consequences     3195
#           instances        4448
#           metaphors        4341
#           uses            24954
# fre       uses             3400
# ger       uses            13687
# heb       uses              829
# ita       uses             8597
# pol       uses             7518
# rus       uses             1863
# spa       uses              783
# dtype: int64

# %% [markdown]
# ## Add Confidence Scores
#
# - 50% of scores are confidence=3
# - 25% of scores are confidence=2
# - 25% of scores are confidence=1

# %%
# get quartile bins for data.rating_std
bins = data.rating_std.quantile([.25, .5, .75, 1]).round(2).values
bins[-1] = 5 # make the max bin something that wouldn't be hit
bin_labels = list(range(len(bins)-1,0, -1))
print("CONFIDENCE <-> RATING_STD BINS")
for i, lab in enumerate(bin_labels):
    print(f"Confidence {lab} is for stdev ranges {bins[i]}-{bins[i+1]}")
display(bins)
data['confidence'] = pd.cut(data.rating_std, bins,
                            include_lowest=True,
                            labels=bin_labels)
data[['rating_std', 'confidence']].sample(2)
# Out:
# CONFIDENCE <-> RATING_STD BINS
# Confidence 3 is for stdev ranges 0.0-0.58
# Confidence 2 is for stdev ranges 0.58-0.82
# Confidence 1 is for stdev ranges 0.82-5.0
# array([0.  , 0.58, 0.82, 5.  ])
#        rating_std confidence
# 3008     0.707107          2
# 49721    0.500000          3

# %%
data.rating_std.hist(bins=20)
# Out:
# <Axes: >

# %% [markdown]
# Different source, by confidence.

# %%
data.confidence = pd.to_numeric(data.confidence)
data[~data.confidence.isna()].groupby('src')['confidence'].aggregate(['mean', 'size']).sort_values('mean', ascending=False).query('size > 100').round(2).head(60)
# Out:
#                                        mean   size
# src
# multiaut_dutch1/multiaut_dutch2        2.78    194
# multiaut_german1                       2.76   4934
# multiaut_italian2                      2.75   5511
# multiaut_polish1                       2.73   5051
# multiaut_italian1                      2.71   3081
# multiaut_dutch2                        2.71    753
# multiaut_russian1                      2.68   1503
# multiaut_german3                       2.67   5929
# snb17                                  2.67   1337
# multiaut_russian2                      2.61    360
# bs12                                   2.57   1248
# betal18                                2.56   1281
# multiaut_dutch3                        2.54    424
# h18/setal08                            2.54   6160
# multiaut_dutch4                        2.51    451
# transdis                               2.45   5014
# motesf                                 2.38   7751
# multiaut_polish1/multiaut_polish2      2.37    320
# h18/multiaut_english6/setal08/snbmo09  2.35    186
# multiaut_dutch1                        2.35   4898
# dod20                                  2.34   3873
# multiaut_french4                       2.31   1553
# multiaut_french3/multiaut_french4      2.30    197
# multiaut_german2                       2.28   2824
# multiaut_french3                       2.24   1282
# multiaut_spanish1                      2.24    769
# hass17                                 2.22    424
# h18/multiaut_english6/setal08          2.20   2261
# snbmo09                                2.16   2491
# multiaut_english2                      2.13   2078
# multiaut_chinese1                      2.11  10782
# multiaut_chinese2                      2.11    561
# multiaut_polish2                       2.09   2147
# multiaut_chinese2/transdis             2.00    131
# multiaut_english3                      1.95   1412
# motesp                                 1.87    928
# multiaut_english2/multiaut_english3    1.86    138
# hmsl                                   1.85   2353
# multiaut_french2                       1.61    368
# multiaut_hebrew1                       1.36    829

# %% [markdown]
# ## Generic Prompt Format

# %% [markdown]
# The training prompts randomly mask parts of the full prompt, to encourage the model to get by without it.
#
# The confidence is based on the standard deviation of the human ratings: imperfect, but aiming for at least a bit of signal about the reliability of the rating.
#
# ### Example Unmasked Prompt:
#
# ```
# ACTION: TAG THE ORIGINALITY OF A RESPONSE TO A CREATIVITY TEST.
# TASK: uses
# PROMPT: علب الصفيح
# TASK QUESTION: ما هو الاستخدام المفاجئ لـ علب الصفيح؟
# LANGUAGE: ara
# RESPONSE: `آلات حادة`
#
# ## Details
# SCALE: 1-5, where 1 is `not original at all` and 5 is `extremely original`
# FORMAT: Return in the format of newline-separated `KEY:value` pairs, with the following fields:
# - `SCORE`: An originality score, 1-5
# - `CONFIDENCE`: A measure of confidence in the score, 1-3, or None.
# - `FLAGS`: A comma-separated list with content flags, such as: 'nonsense', 'violent', 'not practical'
# ```
#
# ### Example Masked Prompt
#
# ```
# TASK: uses
# PROMPT: علب الصفيح
# RESPONSE: `آلات حادة`
# ```
#
# ### Masking probabilities
#
# `task_exclude_prob=0.5, task_type_exclude_prob=0.3, prompt_exclude_prob=0, language_exclude_prob=0.5, question_exclude_prob=0.3, detail_exclude_prob=0.8`
#
# ### Example Response
#
# ```
# SCORE:20
# CONFIDENCE:1
# ```

# %%
for i in range(2):
    a = data.sample(frac=1).iloc[i]
    r = prompter.prepare_example(item=a['prompt'],
                                 response=a['response'],
                                 task_type=a['type'],
                                 question=a['question'],
                                 language=a['language'],
                                 target=a['target'],
                                 confidence=int(float(a['confidence'])),
                                 **prompter.train_probs)
    print(json.dumps(r, indent=2, ensure_ascii=False))
    print('----')
    print(r['messages'][1]['content'])
    print('=====')
# Out:
# {
#   "messages": [
#     {
#       "role": "system",
#       "content": "You are a creativity judge, scoring tests of originality."
#     },
#     {
#       "role": "user",
#       "content": "TASK: uses\nPROMPT: 拖鞋\nLANGUAGE: chi\nRESPONSE: `装饰品`\n\n## Details\nSCALE: 10-50, where 10 is `not original at all` and 50 is `extremely original`\nFORMAT: Return in the format of newline-separated `KEY:value` pairs, with the following fields:\n- `SCORE`: An originality score, 10-50\n- `CONFIDENCE`: A measure of confidence in the score, 1-3, or None."
#     },
#     {
#       "role": "assistant",
#       "content": "SCORE:25\nCONFIDENCE:2"
#     }
#   ]
# }
# ----
# TASK: uses
# PROMPT: 拖鞋
# LANGUAGE: chi
# RESPONSE: `装饰品`
#
# ## Details
# SCALE: 10-50, where 10 is `not original at all` and 50 is `extremely original`
# FORMAT: Return in the format of newline-separated `KEY:value` pairs, with the following fields:
# - `SCORE`: An originality score, 10-50
# - `CONFIDENCE`: A measure of confidence in the score, 1-3, or None.
# =====
# {
#   "messages": [
#     {
#       "role": "system",
#       "content": "You are a creativity judge, scoring tests of originality."
#     },
#     {
#       "role": "user",
#       "content": "TASK: uses\nPROMPT: hat\nLANGUAGE: eng\nRESPONSE: `make it a sled on a snowy day`"
#     },
#     {
#       "role": "assistant",
#       "content": "SCORE:38\nCONFIDENCE:3"
#     }
#   ]
# }
# ----
# TASK: uses
# PROMPT: hat
# LANGUAGE: eng
# RESPONSE: `make it a sled on a snowy day`
# =====

# %% [markdown]
# ## Create Prompts For GPT

# %% [markdown]
# Here is the expected new ChatCompletions format, via https://platform.openai.com/docs/guides/fine-tuning/preparing-your-dataset:
#
# ```
# {"messages": [{"role": "system", "content": "Marv is a factual chatbot that is also sarcastic."}, {"role": "user", "content": "What's the capital of France?"}, {"role": "assistant", "content": "Paris, as if everyone doesn't know that already."}]}
# {"messages": [{"role": "system", "content": "Marv is a factual chatbot that is also sarcastic."}, {"role": "user", "content": "Who wrote 'Romeo and Juliet'?"}, {"role": "assistant", "content": "Oh, just some guy named William Shakespeare. Ever heard of him?"}]}
# {"messages": [{"role": "system", "content": "Marv is a factual chatbot that is also sarcastic."}, {"role": "user", "content": "How far is the Moon from Earth?"}, {"role": "assistant", "content": "Around 384,400 kilometers. Give or take a few, like that really matters."}]}
# ```
#
# There's a system message, user message, then an assistant message. These are saved in a JSONL file.
#
# Example, using `prepare_gpt_from_series`:

# %%
data.sample(1).apply(prompter.prepare_example_from_series, axis=1).tolist()
# Out:
# [{'messages': [{'role': 'system',
#     'content': 'You are a creativity judge, scoring tests of originality.'},
#    {'role': 'user',
#     'content': 'ACTION: TAG THE ORIGINALITY OF A RESPONSE TO A CREATIVITY TEST.\nPROMPT: paperclip\nTASK QUESTION: What is a surprising use for a PAPERCLIP?\nLANGUAGE: eng\nRESPONSE: `keeping craft supplies together`'},
#    {'role': 'assistant', 'content': 'SCORE:15\nCONFIDENCE:3'}]}]

# %% [markdown]
# Export test/validation/train data, as well as a small set for testing training.

# %%
smalldata[['language', 'type']].value_counts()
# Out:
# language  type
# eng       uses            478
# chi       uses            350
# ger       uses            275
# ita       uses            166
# pol       uses            165
# dut       uses            138
# eng       metaphors        91
#           instances        85
# fre       uses             58
# eng       consequences     53
#           completion       48
# rus       uses             42
# ara       uses             23
# spa       uses             17
# heb       uses             11
# Name: count, dtype: int64

# %%
smalldata = data.sample(2000, random_state=42)
smalldata.to_csv(data_dir / 'smalldata.csv', index=False)

for df, suffix in [(smalldata, 'sm'), (data, 'lg')]:
    for splitset in ['default_split']:
        for split in ['train', 'val', 'test']:
            subset = df[df['default_split'] == split].sample(frac=1, random_state=42)
            jsonl = subset.apply(prompter.prepare_example_from_series, axis=1).tolist()
            fname = data_dir / f"{splitset}_{split}_{suffix}_fix.jsonl"
            with open(fname, mode='w', encoding='utf-8') as f:
                # write jsonlines file
                for j in jsonl:
                    f.write(json.dumps(j, ensure_ascii=False))
                    f.write('\n')

# %% [markdown]
# #### Validate Data Format
#
# via https://cookbook.openai.com/examples/chat_finetuning_data_prep
#
# Focus on the biggest file - the full training data.

# %%
fname = data_dir / 'default_split_train_lg_fix.jsonl'

# Load the dataset
with open(fname, 'r', encoding='utf-8') as f:
    dataset = [json.loads(line) for line in f]

# Initial dataset stats
print("Num examples:", len(dataset))
print("First example:")
for message in dataset[0]["messages"]:
    print(message)
# Out:
# Num examples: 80770
# First example:
# {'role': 'system', 'content': 'You are a creativity judge, scoring tests of originality.'}
# {'role': 'user', 'content': 'TASK: uses\nPROMPT: 漏斗\nLANGUAGE: chi\nRESPONSE: `沙漏`'}
# {'role': 'assistant', 'content': 'SCORE:20\nCONFIDENCE:1'}

# %%
# Format error checks
format_errors = defaultdict(int)

for ex in dataset:
    if not isinstance(ex, dict):
        format_errors["data_type"] += 1
        continue
        
    messages = ex.get("messages", None)
    if not messages:
        format_errors["missing_messages_list"] += 1
        continue
        
    for message in messages:
        if "role" not in message or "content" not in message:
            format_errors["message_missing_key"] += 1
        
        if any(k not in ("role", "content", "name", "function_call") for k in message):
            format_errors["message_unrecognized_key"] += 1
        
        if message.get("role", None) not in ("system", "user", "assistant", "function"):
            format_errors["unrecognized_role"] += 1
            
        content = message.get("content", None)
        function_call = message.get("function_call", None)
        
        if (not content and not function_call) or not isinstance(content, str):
            format_errors["missing_content"] += 1
    
    if not any(message.get("role", None) == "assistant" for message in messages):
        format_errors["example_missing_assistant_message"] += 1

if format_errors:
    print("Found errors:")
    for k, v in format_errors.items():
        print(f"{k}: {v}")
else:
    print("No errors found")
# Out:
# No errors found

# %%
encoding = tiktoken.get_encoding("cl100k_base")

# not exact!
# simplified from https://github.com/openai/openai-cookbook/blob/main/examples/How_to_count_tokens_with_tiktoken.ipynb
def num_tokens_from_messages(messages, tokens_per_message=3, tokens_per_name=1):
    num_tokens = 0
    for message in messages:
        num_tokens += tokens_per_message
        for key, value in message.items():
            num_tokens += len(encoding.encode(value))
            if key == "name":
                num_tokens += tokens_per_name
    num_tokens += 3
    return num_tokens

def num_assistant_tokens_from_messages(messages):
    num_tokens = 0
    for message in messages:
        if message["role"] == "assistant":
            num_tokens += len(encoding.encode(message["content"]))
    return num_tokens

def print_distribution(values, name):
    print(f"\n#### Distribution of {name}:")
    print(f"min / max: {min(values)}, {max(values)}")
    print(f"mean / median: {np.mean(values)}, {np.median(values)}")
    print(f"p5 / p95: {np.quantile(values, 0.1)}, {np.quantile(values, 0.9)}")

# %%
# Warnings and tokens counts
n_missing_system = 0
n_missing_user = 0
n_messages = []
convo_lens = []
assistant_message_lens = []

for ex in dataset:
    messages = ex["messages"]
    if not any(message["role"] == "system" for message in messages):
        n_missing_system += 1
    if not any(message["role"] == "user" for message in messages):
        n_missing_user += 1
    n_messages.append(len(messages))
    convo_lens.append(num_tokens_from_messages(messages))
    assistant_message_lens.append(num_assistant_tokens_from_messages(messages))
    
print("Num examples missing system message:", n_missing_system)
print("Num examples missing user message:", n_missing_user)
print_distribution(n_messages, "num_messages_per_example")
print_distribution(convo_lens, "num_total_tokens_per_example")
print_distribution(assistant_message_lens, "num_assistant_tokens_per_example")
n_too_long = sum(l > 4096 for l in convo_lens)
print(f"\n{n_too_long} examples may be over the 4096 token limit, they will be truncated during fine-tuning")
# Out:
# Num examples missing system message: 0
# Num examples missing user message: 0
#
# #### Distribution of num_messages_per_example:
# min / max: 3, 3
# mean / median: 3.0, 3.0
# p5 / p95: 3.0, 3.0
#
# #### Distribution of num_total_tokens_per_example:
# min / max: 46, 259
# mean / median: 93.4138046304321, 80.0
# p5 / p95: 60.0, 161.0
#
# #### Distribution of num_assistant_tokens_per_example:
# min / max: 3, 9
# mean / median: 8.691717221740745, 9.0
# p5 / p95: 9.0, 9.0
#
# 0 examples may be over the 4096 token limit, they will be truncated during fine-tuning

# %%
# Pricing and default n_epochs estimate
MAX_TOKENS_PER_EXAMPLE = 4096

TARGET_EPOCHS = 3
MIN_TARGET_EXAMPLES = 100
MAX_TARGET_EXAMPLES = 25000
MIN_DEFAULT_EPOCHS = 1
MAX_DEFAULT_EPOCHS = 25

n_epochs = TARGET_EPOCHS
n_train_examples = len(dataset)
if n_train_examples * TARGET_EPOCHS < MIN_TARGET_EXAMPLES:
    n_epochs = min(MAX_DEFAULT_EPOCHS, MIN_TARGET_EXAMPLES // n_train_examples)
elif n_train_examples * TARGET_EPOCHS > MAX_TARGET_EXAMPLES:
    n_epochs = max(MIN_DEFAULT_EPOCHS, MAX_TARGET_EXAMPLES // n_train_examples)

n_billing_tokens_in_dataset = sum(min(MAX_TOKENS_PER_EXAMPLE, length) for length in convo_lens)
print(f"Training dataset has ~{n_billing_tokens_in_dataset} tokens that will be charged for during training")
print(f"By default, you'll train for {n_epochs} epochs on this dataset")
print(f"By default, you'll be charged for ~{n_epochs * n_billing_tokens_in_dataset} tokens")
# Out:
# Training dataset has ~7545033 tokens that will be charged for during training
# By default, you'll train for 1 epochs on this dataset
# By default, you'll be charged for ~7545033 tokens

# %%
base_cost = 0.0080 # per 1K
est_cost_train = base_cost * n_epochs * n_billing_tokens_in_dataset / 1000
print(f"Estimated cost for training {n_epochs} epoch is ${est_cost_train:.2f}")
print(f"Est with test/val: ${est_cost_train/.8:.2f}")
print(f"Est for {n_epochs*3} epochs: ${3*est_cost_train/.8:.2f}")
# Out:
# Estimated cost for training 1 epoch is $60.36
# Est with test/val: $75.45
# Est for 3 epochs: $226.35

# %% [markdown]
# ## Upload Train Data to GPT

# %%
#@markdown Upload training files or retrieve already-trained files from OpenAI
sid = dict()

def upload_or_load(fname):
    fname = Path(fname)
    existing_files = [file for file in client.files.list() if file.filename == fname.name]
    if len(existing_files):
        print(f"Using already uploaded file named {fname.name}. If this was unintended, delete the server one.")
        return existing_files[0].id
    else:
        print("Uploading", fname)
        with open(fname, mode='rb') as f:
            results = client.files.create(
                file=f,
                purpose="fine-tune"
                )
        return results.id

for fname in tqdm(data_dir.glob("*_fix.jsonl")):
    sid[fname.name] = upload_or_load(fname)

# to delete everything:
# [client.files.delete(fid) for fid in sid.values()]
    
print("files:", sid.keys())
# Out:
# 0it [00:00, ?it/s]
# Uploading ../../data/training/gpt/default_split_val_lg_fix.jsonl
# Uploading ../../data/training/gpt/default_split_test_full_fix.jsonl
# Uploading ../../data/training/gpt/default_split_test_lg_fix.jsonl
# Uploading ../../data/training/gpt/default_split_val_small_fix.jsonl
# Uploading ../../data/training/gpt/default_split_val_full_fix.jsonl
# Uploading ../../data/training/gpt/default_split_train_lg_fix.jsonl
# Uploading ../../data/training/gpt/default_split_train_small_fix.jsonl
# Uploading ../../data/training/gpt/default_split_test_sm_fix.jsonl
# Uploading ../../data/training/gpt/default_split_train_sm_fix.jsonl
# Uploading ../../data/training/gpt/default_split_train_full_fix.jsonl
# Uploading ../../data/training/gpt/default_split_test_small_fix.jsonl
# Uploading ../../data/training/gpt/default_split_val_sm_fix.jsonl
# files: dict_keys(['default_split_val_lg_fix.jsonl', 'default_split_test_full_fix.jsonl', 'default_split_test_lg_fix.jsonl', 'default_split_val_small_fix.jsonl', 'default_split_val_full_fix.jsonl', 'default_split_train_lg_fix.jsonl', 'default_split_train_small_fix.jsonl', 'default_split_test_sm_fix.jsonl', 'default_split_train_sm_fix.jsonl', 'default_split_train_full_fix.jsonl', 'default_split_test_small_fix.jsonl', 'default_split_val_sm_fix.jsonl'])

# %% [markdown]
# ## Start Train

# %%
set = 'lg' # `sm`` or `lg``; small is a 2000 row subset to ensure everything works #sm2 what a fix for when train probs were wrong
suffix = f'ocsai15-{set}-7-24'
assert len(suffix) <= 18

# %% [markdown]
# Start training. Can't stop after this .. doublecheck that there's enough credit left on your account!
#
# *future note: validation may be unnecessary. At the costs involved, it's not likely that you're tinkering much.*

# %%
model = client.fine_tuning.jobs.create(
  training_file=sid[f'default_split_train_{set}_fix.jsonl'],
  validation_file=sid[f'default_split_val_{set}_fix.jsonl'],
  suffix = suffix,
  model="gpt-3.5-turbo-1106"
)

# for reference: TO DELETE MODEL
#client.models.delete('ft:gpt-3.5-turbo-1106:peter-organisciak:ocsai-small-1-24:8cfMjxJN')

# %%
print("Hyper parameters", client.fine_tuning.jobs.retrieve(model.id).hyperparameters)
# Out:
# Hyper parameters Hyperparameters(n_epochs='auto', batch_size='auto', learning_rate_multiplier='auto')

# %%
from wandb.integration.openai.fine_tuning import WandbLogger
WandbLogger.sync(fine_tune_job_id=model.id)
# Out:
# wandb: Retrieving fine-tune job...
# Tracking run with wandb version 0.17.4
# Run data is saved locally in <code>/Users/peter.organisciak/Library/CloudStorage/GoogleDrive-organisciak@gmail.com/My Drive/Projects/ocsai-py/notebooks/ocsai2-dataprep/wandb/run-20240703_205505-ftjob-glhBvS5SwP6PYYclnEDbbtEz</code>
# Syncing run <strong><a href='https://wandb.ai/massive-texts/OpenAI-Fine-Tune/runs/ftjob-glhBvS5SwP6PYYclnEDbbtEz' target="_blank">ftjob-glhBvS5SwP6PYYclnEDbbtEz</a></strong> to <a href='https://wandb.ai/massive-texts/OpenAI-Fine-Tune' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/massive-texts/OpenAI-Fine-Tune' target="_blank">https://wandb.ai/massive-texts/OpenAI-Fine-Tune</a>
#  View run at <a href='https://wandb.ai/massive-texts/OpenAI-Fine-Tune/runs/ftjob-glhBvS5SwP6PYYclnEDbbtEz' target="_blank">https://wandb.ai/massive-texts/OpenAI-Fine-Tune/runs/ftjob-glhBvS5SwP6PYYclnEDbbtEz</a>
# wandb: Waiting for the OpenAI fine-tuning job to finish training...
# wandb: To avoid blocking, you can call `WandbLogger.sync` with `wait_for_job_success=False` after OpenAI training completes.
# wandb: Fine-tuning finished, logging metrics, model metadata, and run metadata to Weights & Biases
# wandb: Logging training/validation files...
# VBox(children=(Label(value='85.236 MB of 85.267 MB uploaded\r'), FloatProgress(value=0.9996295245035809, max=1…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>fine_tuned_model</td><td>ft:gpt-3.5-turbo-110...</td></tr><tr><td>status</td><td>succeeded</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">ftjob-glhBvS5SwP6PYYclnEDbbtEz</strong> at: <a href='https://wandb.ai/massive-texts/OpenAI-Fine-Tune/runs/ftjob-glhBvS5SwP6PYYclnEDbbtEz' target="_blank">https://wandb.ai/massive-texts/OpenAI-Fine-Tune/runs/ftjob-glhBvS5SwP6PYYclnEDbbtEz</a><br/> View project at: <a href='https://wandb.ai/massive-texts/OpenAI-Fine-Tune' target="_blank">https://wandb.ai/massive-texts/OpenAI-Fine-Tune</a><br/>Synced 6 W&B file(s), 2 media file(s), 7 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20240703_205505-ftjob-glhBvS5SwP6PYYclnEDbbtEz/logs</code>
# The new W&B backend becomes opt-out in version 0.18.0; try it out with `wandb.require("core")`! See https://wandb.me/wandb-core for more information.
# '🎉 wandb sync completed successfully'

# %%
# check in every few minutes to see training status
while True:
    status = client.fine_tuning.jobs.retrieve(model.id)
    print(status.status)
    if status.status not in ['running', 'pending', 'validating_files']:
        break
    if status.status == 'running':
        time.sleep(60)
    elif status.status in ['pending', 'validating_files']:
        print(status)
        time.sleep(5*60)
    else:
        break
status
# Out:
# succeeded
# FineTuningJob(id='ftjob-5Pbn7CQPO8u3z5SeNuq9IXSB', created_at=1704319430, error=None, fine_tuned_model='ft:gpt-3.5-turbo-1106:peter-organisciak:ocsai-full-1-24:8d5RLryO', finished_at=1704326395, hyperparameters=Hyperparameters(n_epochs=1, batch_size=53, learning_rate_multiplier=2), model='gpt-3.5-turbo-1106', object='fine_tuning.job', organization_id='org-48rfjyoSnZfLJWOte33sjuqL', result_files=['file-Iq1Q3AeeXKStpPV4rKBJx9XI'], status='succeeded', trained_tokens=7687449, training_file='file-gTx9PdkFq4aaptjlRfoCptL6', validation_file='file-TB49njVn1PWGB5SHbH869Xc9')

# %% [markdown]
# ## Test Fine-tune

# %%
models = {
    "small": "ft:gpt-3.5-turbo-1106:peter-organisciak:ocsai15-small-7-24:9h47cC2o",
    "full": "ft:gpt-3.5-turbo-1106:peter-organisciak:ocsai-full-1-24:8d5RLryO"
}

# %% [markdown]
# For here, just evaluate on data that has been processed identically to the training data (with the same masking). Other conditions can be measured elsewhere.

# %%
from ocsai.prompter import GPT_SYS_MSG
from ocsai.inference import Chat_Scorer
scorer = Chat_Scorer(model_dict=models, cache='../data/test_cache')

# %%
#smalldata = pd.read_csv(data_dir / 'smalldata.csv')
#testdata = smalldata[smalldata.default_split == 'test'].copy()
#testdata = data[data.default_split == 'test'].sample(400, random_state=42).copy()

# %%
all_scored['score'] = pd.to_numeric(all_scored['score'], errors='raise')
all_scored['predict_confidence'] = pd.to_numeric(all_scored['predict_confidence'], errors='raise')

print("overall corr", all_scored[['target', 'score']].corr().round(2).iloc[0,1])

print("How well does predicted confidence correlate with actual confidence?")
print(all_scored[['confidence', 'predict_confidence']].corr().round(2).iloc[0,1])

print("Correlation by predicted confidence")
all_scored.groupby('predict_confidence')[['target', 'score']].corr().iloc[::2, 1].round(2)

# correlation of target and score column
from scipy.stats import pearsonr
def stats(x):
    corr, p_val, conf_corr = np.nan, np.nan, np.nan
    nans = x[['target', 'score']].isna().any(axis=1)
    if (~nans).sum() > 10:
        corr, p_val = pearsonr(x[~nans]['target'], x[~nans]['score'])

    nans = x[['confidence', 'predict_confidence']].isna().any(axis=1)
    if (~nans).sum() > 10:
        conf_corr = pearsonr(x[~nans]['confidence'], x[~nans]['predict_confidence'])[0]

    return pd.Series({
        'n': len(x),
        'corr': np.round(corr, 2),
        'p_val': np.round(p_val, 3),
        'conf_corr': np.round(conf_corr, 2),
        'rmse': np.round(np.sqrt(np.mean((x['target'] - x['score'])**2)), 3)
    })
x = all_scored.groupby(['language', 'type']).apply(stats)
x[~x['corr'].isna()].sort_values('corr')
# Out:
# overall corr 0.56
# How well does predicted confidence correlate with actual confidence?
# 0.12
# Correlation by predicted confidence
#                     n  corr  p_val  conf_corr  rmse
# language type
# pol      uses  1000.0  0.56    0.0       0.12  0.54

# %%
all_scored[all_scored['language'] == 'ara'][['target', 'score']].corr()
# Out:
#           target     score
# target  1.000000  0.285911
# score   0.285911  1.000000

# %%
all_scored.groupby(['language']).apply(stats)
# Out:
#               n  corr  p_val  conf_corr   rmse
# language
# ara       148.0  0.29    0.0        NaN  1.145
# chi       252.0  0.47    0.0      -0.04  0.418
